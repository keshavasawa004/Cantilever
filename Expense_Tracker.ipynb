# %% [markdown]
# <a href="https://colab.research.google.com/github/keshavasawa004/Cantilever/blob/main/Expense_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from datetime import datetime

expense_file = "expenses.csv"

if not os.path.exists(expense_file):
    df = pd.DataFrame(columns=["Date", "Category", "Amount"])
    df.to_csv(expense_file, index=False)

# %%
def add_expense(date, category, amount):
    df = pd.read_csv(expense_file)
    new_expense = pd.DataFrame([{"Date": date, "Category": category, "Amount": amount}])
    df = pd.concat([df, new_expense], ignore_index=True)
    df.to_csv(expense_file, index=False)
    print(f"Expense of {amount} added under '{category}' on {date}")

def view_expenses():
    df = pd.read_csv(expense_file)
    print(df)

def summary_by_category():
    df = pd.read_csv(expense_file)
    summary = df.groupby("Category")["Amount"].sum()
    print(summary)

def plot_expenses():
    df = pd.read_csv(expense_file)
    if df.empty:
        print("No expenses to plot.")
        return
    summary = df.groupby("Category")["Amount"].sum()
    summary.plot(kind='bar', figsize=(8, 5), color='skyblue')
    plt.title("Expenses by Category")
    plt.ylabel("Amount")
    plt.show()

# %%
while True:
    print("\n💰 Expense Tracker")
    print("1. Add Expense")
    print("2. View All Expenses")
    print("3. Summary by Category")
    print("4. Plot Expenses by Category")
    print("5. Exit")

    choice = input("Enter choice: ")

    if choice == '1':
        date = input("Enter date (YYYY-MM-DD) or leave blank for today: ")
        if not date:
            date = datetime.now().strftime("%Y-%m-%d")
        category = input("Enter category: ")
        amount = float(input("Enter amount: "))
        add_expense(date, category, amount)

    elif choice == '2':
        view_expenses()

    elif choice == '3':
        summary_by_category()

    elif choice == '4':
        plot_expenses()

    elif choice == '5':
        print("Goodbye!")
        break

    else:
        print("Invalid choice. Please try again.")
# Out:
# 💰 Expense Tracker
# 1. Add Expense
# 2. View All Expenses
# 3. Summary by Category
# 4. Plot Expenses by Category
# 5. Exit
# Enter choice: 1
# Enter date (YYYY-MM-DD) or leave blank for today: 2025-08-09
# Enter category: Shopping
# Enter amount: 100000
# /tmp/ipython-input-3297700510.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, new_expense], ignore_index=True)
# Expense of 100000.0 added under 'Shopping' on 2025-08-09
#
# 💰 Expense Tracker
# 1. Add Expense
# 2. View All Expenses
# 3. Summary by Category
# 4. Plot Expenses by Category
# 5. Exit
# Enter choice: 2
#          Date  Category    Amount
# 0  2025-08-09  Shopping  100000.0
#
# 💰 Expense Tracker
# 1. Add Expense
# 2. View All Expenses
# ...
